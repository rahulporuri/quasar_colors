# %%
ls *.fits
# Out:
# spec-0916-52378-0576.fits  spec-1256-52902-0148.fits  spec-2555-54265-0178.fits
# spec-1246-53783-0084.fits  spec-1256-52902-0470.fits  spec-2555-54265-0179.fits
# spec-1250-52930-0345.fits  spec-1256-52902-0480.fits  spec-2555-54265-0187.fits
# spec-1250-52930-0554.fits  spec-1256-52902-0495.fits  spec-2555-54265-0201.fits
# spec-1250-52930-0555.fits  spec-1256-52902-0507.fits  spec-2555-54265-0442.fits
# spec-1250-52930-0560.fits  spec-1256-52902-0546.fits  spec-2555-54265-0499.fits
# spec-1250-52930-0591.fits  spec-1256-52902-0564.fits  spec-2555-54265-0520.fits
# spec-1250-52930-0629.fits  spec-1257-52944-0016.fits  spec-2565-54329-0003.fits
# spec-1251-52964-0008.fits  spec-1257-52944-0058.fits  spec-2565-54329-0076.fits
# spec-1251-52964-0024.fits  spec-1257-52944-0091.fits  spec-2565-54329-0078.fits
# spec-1251-52964-0027.fits  spec-1257-52944-0118.fits  spec-2565-54329-0144.fits
# spec-1251-52964-0118.fits  spec-1257-52944-0151.fits  spec-2565-54329-0152.fits
# ...

# %%
import pyfits as pf
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
tmp = 'spec-0916-52378-0576.fits'
x =np.arange(np.power(10,pf.getheader(tmp,0)['coeff0']), np.power(10,pf.getheader(tmp,0)['coeff0'])+ np.power(10,pf.getheader(tmp,0)['coeff1'])* len(pf.getdata(tmp,1)), np.power(10,pf.getheader(tmp,0)['coeff1']))
plt.plot(x,pf.getdata('spec-0916-52378-0576.fits',1))

# %%
plt.plot(pf.getdata('spec-1246-53783-0084.fits',1))

# %%
plt.plot(pf.getdata('spec-1250-52930-0345.fits',1))
plt.plot(pf.getdata('spec-1250-52930-0554.fits',1))
plt.plot(pf.getdata('spec-1250-52930-0555.fits',1))
plt.plot(pf.getdata('spec-1250-52930-0560.fits',1))
plt.plot(pf.getdata('spec-1250-52930-0591.fits',1))
plt.plot(pf.getdata('spec-1250-52930-0629.fits',1))

# %%
plt.plot(pf.getdata('spec-1251-52964-0008.fits',1))
plt.plot(pf.getdata('spec-1251-52964-0024.fits',1))
plt.plot(pf.getdata('spec-1251-52964-0027.fits',1))
plt.plot(pf.getdata('spec-1251-52964-0118.fits',1))
plt.plot(pf.getdata('spec-1251-52964-0125.fits',1))
plt.plot(pf.getdata('spec-1251-52964-0129.fits',1))
plt.plot(pf.getdata('spec-1251-52964-0136.fits',1))
plt.plot(pf.getdata('spec-1251-52964-0157.fits',1))
plt.plot(pf.getdata('spec-1251-52964-0160.fits',1))
plt.plot(pf.getdata('spec-1251-52964-0161.fits',1))
plt.plot(pf.getdata('spec-1251-52964-0164.fits',1))
plt.plot(pf.getdata('spec-1251-52964-0176.fits',1))
plt.plot(pf.getdata('spec-1251-52964-0186.fits',1))

# %%
plt.plot(pf.getdata('spec-1256-52902-0032.fits',1))
plt.plot(pf.getdata('spec-1256-52902-0062.fits',1))
plt.plot(pf.getdata('spec-1256-52902-0065.fits',1))
plt.plot(pf.getdata('spec-1256-52902-0068.fits',1))
plt.plot(pf.getdata('spec-1256-52902-0069.fits',1))
plt.plot(pf.getdata('spec-1256-52902-0070.fits',1))
plt.plot(pf.getdata('spec-1256-52902-0075.fits',1))
plt.plot(pf.getdata('spec-1256-52902-0105.fits',1))
plt.plot(pf.getdata('spec-1256-52902-0148.fits',1))
plt.plot(pf.getdata('spec-1256-52902-0470.fits',1))
plt.plot(pf.getdata('spec-1256-52902-0480.fits',1))
plt.plot(pf.getdata('spec-1256-52902-0495.fits',1))
plt.plot(pf.getdata('spec-1256-52902-0507.fits',1))
plt.plot(pf.getdata('spec-1256-52902-0546.fits',1))
plt.plot(pf.getdata('spec-1256-52902-0564.fits',1))

# %%
plt.plot(pf.getdata('spec-1257-52944-0016.fits',1))
plt.plot(pf.getdata('spec-1257-52944-0058.fits',1))
plt.plot(pf.getdata('spec-1257-52944-0091.fits',1))
plt.plot(pf.getdata('spec-1257-52944-0118.fits',1))
plt.plot(pf.getdata('spec-1257-52944-0151.fits',1))
plt.plot(pf.getdata('spec-1257-52944-0152.fits',1))
plt.plot(pf.getdata('spec-1257-52944-0160.fits',1))
plt.plot(pf.getdata('spec-1257-52944-0210.fits',1))

# %%
plt.plot(pf.getdata('spec-1452-53112-0210.fits',1))

# %%
plt.plot(pf.getdata('spec-2072-53430-0143.fits',1))

# %%
plt.plot(pf.getdata('spec-2194-53904-0198.fits',1))

# %%
plt.plot(pf.getdata('spec-2325-54082-0043.fits',1))

# %%
plt.plot(pf.getdata('spec-2354-53799-0075.fits',1))

# %%
plt.plot(pf.getdata('spec-2555-54265-0012.fits',1))
plt.plot(pf.getdata('spec-2555-54265-0020.fits',1))
plt.plot(pf.getdata('spec-2555-54265-0027.fits',1))
plt.plot(pf.getdata('spec-2555-54265-0039.fits',1))
plt.plot(pf.getdata('spec-2555-54265-0065.fits',1))
plt.plot(pf.getdata('spec-2555-54265-0126.fits',1))
plt.plot(pf.getdata('spec-2555-54265-0166.fits',1))
plt.plot(pf.getdata('spec-2555-54265-0168.fits',1))
plt.plot(pf.getdata('spec-2555-54265-0171.fits',1))
plt.plot(pf.getdata('spec-2555-54265-0178.fits',1))
plt.plot(pf.getdata('spec-2555-54265-0179.fits',1))
plt.plot(pf.getdata('spec-2555-54265-0187.fits',1))
plt.plot(pf.getdata('spec-2555-54265-0201.fits',1))
plt.plot(pf.getdata('spec-2555-54265-0442.fits',1))
plt.plot(pf.getdata('spec-2555-54265-0499.fits',1))
plt.plot(pf.getdata('spec-2555-54265-0520.fits',1))

# %%
plt.plot(pf.getdata('spec-2565-54329-0003.fits',1))
plt.plot(pf.getdata('spec-2565-54329-0076.fits',1))
plt.plot(pf.getdata('spec-2565-54329-0078.fits',1))
plt.plot(pf.getdata('spec-2565-54329-0144.fits',1))
plt.plot(pf.getdata('spec-2565-54329-0152.fits',1))
plt.plot(pf.getdata('spec-2565-54329-0160.fits',1))
plt.plot(pf.getdata('spec-2565-54329-0205.fits',1))
plt.plot(pf.getdata('spec-2565-54329-0208.fits',1))
plt.plot(pf.getdata('spec-2565-54329-0210.fits',1))

# %%
plt.plot(pf.getdata('spec-2596-54207-0565.fits',1))

# %%
plt.plot(pf.getdata('spec-2945-54505-0306.fits',1))

# %%
plt.plot(pf.getdata('spec-3368-54954-0417.fits',1))

# %%
plt.plot(pf.getdata('spec-3806-55505-0338.fits',1))

# %%
plt.plot(pf.getdata('spec-4293-55509-0948.fits',1))

# %%
plt.plot(pf.getdata('spec-4347-55830-0732.fits',1))

# %%
plt.plot(pf.getdata('spec-4409-55883-0141.fits',1))

# %%
plt.plot(pf.getdata('spec-4464-55866-0714.fits',1))

# %%
plt.plot(pf.getdata('spec-4685-55657-0133.fits',1))

# %%
plt.plot(pf.getdata('spec-4997-55738-0704.fits',1))

# %%
plt.plot(pf.getdata('spec-6012-56101-0722.fits',1))

# %%
import glob
import os
list = sorted(glob.glob('spectra/*.fits'))
# Out:
# ['spectra/spec-0916-52378-0576.fits', 'spectra/spec-1246-53783-0084.fits', 'spectra/spec-1250-52930-0345.fits', 'spectra/spec-1250-52930-0554.fits', 'spectra/spec-1250-52930-0555.fits', 'spectra/spec-1250-52930-0560.fits', 'spectra/spec-1250-52930-0591.fits', 'spectra/spec-1250-52930-0629.fits', 'spectra/spec-1251-52964-0008.fits', 'spectra/spec-1251-52964-0024.fits', 'spectra/spec-1251-52964-0027.fits', 'spectra/spec-1251-52964-0118.fits', 'spectra/spec-1251-52964-0125.fits', 'spectra/spec-1251-52964-0129.fits', 'spectra/spec-1251-52964-0136.fits', 'spectra/spec-1251-52964-0157.fits', 'spectra/spec-1251-52964-0160.fits', 'spectra/spec-1251-52964-0161.fits', 'spectra/spec-1251-52964-0164.fits', 'spectra/spec-1251-52964-0176.fits', 'spectra/spec-1251-52964-0186.fits', 'spectra/spec-1256-52902-0032.fits', 'spectra/spec-1256-52902-0062.fits', 'spectra/spec-1256-52902-0065.fits', 'spectra/spec-1256-52902-0068.fits', 'spectra/spec-1256-52902-0069.fits', 'spectra/spec-1256-52902-0070.fits'
# ...

# %%
for j in xrange(len(list)):
    print list[j], np.power(10,pf.getheader(list[j],0)['coeff0']), np.power(10,pf.getheader(list[j],0)['coeff0'])+ np.power(10,pf.getheader(list[j],0)['coeff1'])* len(pf.getdata(list[j],1)), np.power(10,pf.getheader(list[j],0)['coeff1']), len(pf.getdata(list[j],1)), pf.getheader(list[j],0)['PLUG_RA'], pf.getheader(list[j],0)['PLUG_DEC']
# Out:
#  spectra/spec-0916-52378-0576.fits
# 3801.01864555
# 7631.90063718 1.00023028502
# 3830 213.6433
# -1.2595657
# spectra/spec-1246-53783-0084.fits
# 3813.29145277
# 7639.17229297 1.00023028502
# 3825 86.412468
# -1.0098461
# spectra/spec-1250-52930-0345.fits 3797.51938971
# 7619.39930878 1.00023028502 3821
# 64.064706 27.654165
# spectra/spec-1250-52930-0554.fits
# 3797.51938971
# 7631.4020722 1.00023028502 3833
# 65.969224 27.081051
# spectra/spec-1250-52930-0555.fits 3797.51938971
# 7631.4020722 1.00023028502 3833
# 66.004357 27.04396
# spectra/spec-1250-52930-0560.fits
# 3797.51938971
# 7630.40184191 1.00023028502 3832
# 66.051513 26.982523
# spectra/spec-1250-52930-0591.fits
# 3797.51938971
# 7623.40022992 1.00023028502 3825
# 66.154343 27.001068
# spectra/spec-1250-52930-0629.fits
# 3797.51938971
# 7611.3974665 1.00023028502 3813
# 66.509747 26.877298
# spectra/spec-1251-52964-0008.fits
# 3809.78089846
# 7635.66173867
# 1.00023028502 3825
# 65.594917 27.523908
# ...

# %%
tmp = 'spectra/spec-0916-52378-0576.fits'
pf.getheader(tmp,0)['plug_ra']
# Out:
# 213.6433
